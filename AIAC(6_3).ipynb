# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51819/AI-AC-K.SAICHARAN/blob/main/AIAC(6_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 1: Classes – Student Class

class Student:
    def __init__(self, name, roll_number, branch):
        self.name = name
        self.roll_number = roll_number
        self.branch = branch

    def display_details(self):
        print("Student Name:", self.name)
        print("Roll Number:", self.roll_number)
        print("Branch:", self.branch)


# Creating an object
student1 = Student("Sai Charan Teja", "2303A51819", "CSE")
student1.display_details()
# Out:
# Student Name: Sai Charan Teja
# Roll Number: 2303A51819
# Branch: CSE

# %%
#Task 2: Loops – First 10 Multiples of a Number
def print_multiples_for(num):
    print(f"First 10 multiples of {num}:")
    for i in range(1, 11):
        print(num * i)


print_multiples_for(5)
def print_multiples_while(num):
    i = 1
    print(f"First 10 multiples of {num}:")
    while i <= 10:
        print(num * i)
        i += 1


print_multiples_while(5)
# Out:
# First 10 multiples of 5:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
# First 10 multiples of 5:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
#Task 3: Conditional Statements – Age Classification
def classify_age(age):
    if age < 13:
        return "Child"
    elif age < 20:
        return "Teenager"
    elif age < 60:
        return "Adult"
    else:
        return "Senior"


print(classify_age(10))
print(classify_age(17))
print(classify_age(25))
print(classify_age(65))
# Out:
# Child
# Teenager
# Adult
# Senior

# %%
#Task 4: Sum of First n Natural Numbers
def sum_to_n_for(n):
    total = 0
    for i in range(1, n + 1):
        total += i
    return total


print(sum_to_n_for(10))
def sum_to_n_while(n):
    total = 0
    i = 1
    while i <= n:
        total += i
        i += 1
    return total


print(sum_to_n_while(10))
def sum_to_n_formula(n):
    return n * (n + 1) // 2


print(sum_to_n_formula(10))
# Out:
# 55
# 55
# 55

# %%
#Task 5: Classes – Bank Account Class
# Bank Account Class

class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited ₹{amount}")
        else:
            print("Invalid deposit amount")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"Withdrawn ₹{amount}")
        else:
            print("Insufficient balance")

    def check_balance(self):
        print(f"Current Balance: ₹{self.balance}")


# Testing the class
account = BankAccount("Sai Charan", 1000)
account.check_balance()
account.deposit(500)
account.withdraw(300)
account.check_balance()
# Out:
# Current Balance: ₹1000
# Deposited ₹500
# Withdrawn ₹300
# Current Balance: ₹1200
